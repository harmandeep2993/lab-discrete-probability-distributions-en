# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.stats import binom

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""
apples = 60
oranges = 40

# calculate total oranges
total_fruits= apples + oranges

#---> 1. What is the probability that the fruit is apple?
p = apples / total_fruits
print(f"The probability that fruit is apple: {p:.2f}")

#---> 2. What is the probability that the fruit is oranges?
q = oranges / total_fruits
print(f"The probability that fruit is orange: {q:.2f}")
# Out:
# The probability that fruit is apple: 0.60
# The probability that fruit is orange: 0.40

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# random sample size
n = 20

# What is the probability that the first 5 fruits are all apples?
prob_5_apples = binom.pmf(k=5, n=5, p=p)
print(f"Probability that the first 5 fruits are all apples: {prob_5_apples}")

# What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?
prob_15_organges = binom.pmf(k=15, n=15, p=q)
print(f"The Probability that next 15 fruits are oranges: {prob_15_organges}")

# combine probability
prob_squence = prob_5_apples * prob_15_organges
print(f"The probability that the first 5 fruits are all apples and the next 15 fruits are all oranges: {prob_squence}")
# Out:
# Probability that the first 5 fruits are all apples: 0.07776
# The Probability that next 15 fruits are oranges: 1.0737418240000018e-06
# The probability that the first 5 fruits are all apples and the next 15 fruits are all oranges: 8.349416423424014e-08

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
# your solution here

prob_5_apples_no_sequence = binom.pmf(k=5, n= 20, p=p)
print("Probability first 5 apples without order:", prob_5_apples_no_sequence)

prob_15_ornages_no_sequence = binom.pmf(k= 15, n= 20, p=q)
print("Probability that 15 ornages without order:", prob_15_ornages_no_sequence)
# Out:
# Probability first 5 apples without order: 0.0012944935222876579
# Probability that 15 ornages without order: 0.0012944935222876579

# %%
# your solution here
prob_without_sequence = prob_5_apples_no_sequence * prob_15_ornages_no_sequence

print(f"Probability of 5 apples and 15 oranges: {prob_without_sequence:.6f}")
# Out:
# Probability of 5 apples and 15 oranges: 0.000002

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
# your code here

prob_less_than_5 = binom.cdf(k= 4, n= 20, p= p)

print(f"The probability that less than 5 fruits picked are apples: {prob_less_than_5}")
# Out:
# The probability that less than 5 fruits picked are apples: 0.00031703112116863037

# %% [markdown]
# <!-- **Plot the PDF (probability distributiom function) for the above binomial distribution.** -->
#
# **Plot the Probability Mass Function (PMF) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
# your code here
# Please label the axes and give a title to the plot 

x = np.arange(0, n+1)
prob_pmf = binom.pmf(x , n, p)

plt.figure(figsize=(8, 6))
plt.bar(x, prob_pmf)
plt.xlabel("Number of apples")
plt.ylabel("Probability")
plt.title("Binomial PMF (n=20, p=0.6)")
plt.show()

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
# your code here 

import math

# Given values
lam = 2.3   # average goals
k = 5       # number of goals

# Poisson probability
prob_5_goals = (math.exp(-lam) * (lam ** k)) / math.factorial(k)

print("Probability of exactly 5 goals:", prob_5_goals)
# Out:
# Probability of exactly 5 goals: 0.0537750255819468

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
# your code here
# Please label the axes and give a title to the plot 

# Range of goals
goals = list(range(0, 11))

# Poisson probabilities
poisson_probs = [
    (math.exp(-lam) * (lam ** g)) / math.factorial(g)
    for g in goals
]

# Plot
plt.figure(figsize=(7, 4))
plt.bar(goals, poisson_probs)

plt.xlabel("Number of Goals")
plt.ylabel("Probability")
plt.title("Poisson Distribution of Goals (λ = 2.3)")
plt.tight_layout()
plt.show()
